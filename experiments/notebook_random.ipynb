# %%
import sys
import time

sys.path.append('..')
from back import facades, AlgoRandom
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2023-02-13 15:55:11.204271: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/rl/lib/python3.10/site-packages/requests/compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
# ...

# %%
game = facades.grid_world_5x5()

random = AlgoRandom()

model = random.use(game,random,1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 game = facades.grid_world_5x5()
#       3 random = Rand()
#       5 model = random.use(game,random,1000)
#
# NameError: name 'facades' is not defined
